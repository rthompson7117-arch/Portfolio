# %%
projects = ["Data Science", "Python Automation", "AI Tools"]

for project in projects:
  clean = project.lower().replace(" ", "_")
  print(clean)


  """
  OR
  for project in projects:
    print(project.lower().replace(" ","_"))
  """
# Out:
#   File "/tmp/ipykernel_929/642352102.py", line 8
#     """
#     ^
# SyntaxError: incomplete input
