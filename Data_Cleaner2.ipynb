# %%
"""
 Spreadsheet Data Cleaner

Companies often have messy spreadsheets.

Python can:

removes duplicates

standardizes text

cleans columns

Example Code

Input:

Name        City
john smith  new york
Jane Smith  NEW YORK

Output:

John Smith  New York
Jane Smith  New York
Example Code
import pandas as pd
"""

df = pd.read_csv("data.csv")

df["Name"] = df["Name"].str.title()
df["City"] = df["City"].str.title()

df.to_csv("cleaned.csv", index=False)
