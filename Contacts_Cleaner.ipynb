# %%
contacts = ["  Ryan  Thompson  ", "SARAH smith", "mIKe Jordan", " anna lee "]

usernames = []

for contact in contacts:
  clean = contact.strip().lower().replace(" ", "_")
  usernames.append(clean)
  print(clean)

print()
print(cleaned_contacts)
# Out:
# ryan__thompson
# sarah_smith
# mike_jordan
# anna_lee
#
# []
