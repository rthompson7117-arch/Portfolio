# %% [markdown]
# <a href="https://colab.research.google.com/github/rthompson7117-arch/Portfolio/blob/main/Batch_Renaming_Any_File_Type_from_Outside_Folder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

def rename_images(folder_path):

  files = sorted(oslistdir(folder_path))

  count = 1

  for file in files:
    name, ext = os.path.splitext(file)

    if ext.lower() in [".jpg", ".png", ".jpeg"]:

      old_path = os.path.join(folder_path, file)

      new_name = f"image {count}{ext}"
      new_path = os.path.join(folder_path, new_name)

      os.rename(old_path, new_path)

      print(f"Renamed {file} -> {new_name}")

      count += 1

folder = "photos"

rename_images(folder)
