# %% [markdown]
# <a href="https://colab.research.google.com/github/rthompson7117-arch/Portfolio/blob/main/Email_Cleaner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv

seen_emails = set()

with open("contacts.csv, "r", newline="", encoding="utf-8")
  open("cleaned_contacts.csv", "w", newline="", encoding="utf-8") as outfile:

    reader = csv.DictReader(infile)

    fieldnames = ["name", "email"]
    writer = csv.DictWriter(outfile, fieldnames=fieldnames)

    writer.writeheader()

    for row in reader:
      name = row["name"].strip().title()
      email = row["email"].strip().lower()

      if email not in seen_emails:
          seen_emails.add(email)

        writer.writerow({
          "name": name,
          "email": email
        })
# Out:
#   File "<tokenize>", line 36
#     writer.writerow({
#     ^
# IndentationError: unindent does not match any outer indentation level
