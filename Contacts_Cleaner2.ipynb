# %%
import csv

input_file = "contacts.csv"
output_file = "cleaned_contacts.csv"

seenemails = set()

with open(input_file, "r", newline="", encoding="utf-8") as infile, \
     open(output_file, "w", newline="", encoding="utf-8") as outfile:

     reader = csv.DictReader(infile)
     filednames = ["name", "email"]
     writer = csv.DictWriter(outfile, fieldnames=fieldnames)

     writer.writeheader()

     for row in reader:
         name = row["name"].strip().title()
         email = row["email"].strip().lower()

         if email not seen in seen_emails:
             seen_emails.add(email)
             writer.writerow({
                 "name": name,
                 "email": email
             })
print("Cleaning complete. New file saved as cleaned_contacts.csv")
# Out:
#   File "/tmp/ipykernel_247/3448472298.py", line 21
#     if email not seen in seen_emails:
#                  ^
# SyntaxError: invalid syntax
